# %% [markdown]
# # QQ Plot to prob normal Distribution

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(df["sepal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
temp=sorted((df["sepal_length"]).tolist())

# %%
x_quant=[]
for i in range(1, 101):
    x_quant.append(np.percentile(temp, i))

# %%
x_quant
# Out:
# [np.float64(4.4),
#  np.float64(4.4),
#  np.float64(4.547),
#  np.float64(4.6),
#  np.float64(4.6),
#  np.float64(4.694),
#  np.float64(4.743),
#  np.float64(4.8),
#  np.float64(4.8),
#  np.float64(4.8),
#  np.float64(4.9),
#  np.float64(4.9),
#  np.float64(4.9),
#  np.float64(4.9),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.029),
#  np.float64(5.1),
#  np.float64(5.1),
#  np.float64(5.1),
#  np.float64(5.1),
#  np.float64(5.1),
#  np.float64(5.123),
#  np.float64(5.2),
#  np.float64(5.2),
#  np.float64(5.27),
#  np.float64(5.4),
#  np.float64(5.4),
#  np.float64(5.4),
#  np.float64(5.4),
#  np.float64(5.5),
#  np.float64(5.5),
#  np.float64(5.5),
#  np.float64(5.5),
#  np.float64(5.511),
#  np.float64(5.6),
#  np.float64(5.6),
#  np.float64(5.6),
#  np.float64(5.606999999999999),
#  np.float64(5.7),
#  np.float64(5.7),
#  np.float64(5.7),
#  np.float64(5.7),
#  np.float64(5.7),
# ...

# %%
samples=np.random.normal(loc=0, scale=1, size=1000)

# %%
y_quant=[]

for i in range(1, 101):
    y_quant.append(np.percentile(samples, i))

# %%
y_quant
# Out:
# [np.float64(-2.1448390534250854),
#  np.float64(-1.8873643909178133),
#  np.float64(-1.7206708549430143),
#  np.float64(-1.6077976726343066),
#  np.float64(-1.5399484603389366),
#  np.float64(-1.46875078118912),
#  np.float64(-1.3950300478158542),
#  np.float64(-1.2968567191481313),
#  np.float64(-1.2239884651105004),
#  np.float64(-1.1867600115163308),
#  np.float64(-1.1291760042718006),
#  np.float64(-1.0470741996358308),
#  np.float64(-1.0032169672085838),
#  np.float64(-0.9481784654821681),
#  np.float64(-0.9120631531764748),
#  np.float64(-0.8841202689026438),
#  np.float64(-0.8393177935415308),
#  np.float64(-0.8111347398504607),
#  np.float64(-0.7687899614607596),
#  np.float64(-0.74356975388675),
#  np.float64(-0.6959232748963285),
#  np.float64(-0.6700801414882267),
#  np.float64(-0.6403731201830155),
#  np.float64(-0.6046130578825578),
#  np.float64(-0.5869018737596662),
#  np.float64(-0.5495716024720505),
#  np.float64(-0.5261970658875899),
# ...

# %%
sns.scatterplot(x=x_quant, y=y_quant)
# Out:
# <Axes: >

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
fig=sm.qqplot(df["sepal_length"], line="45", fit=True)
plt.title("QQ plot")
plt.show()

# %%
x=np.random.uniform(low=0, high=1, size=10000)

# %%
plt.hist(x)
# Out:
# (array([ 955.,  998.,  947., 1008., 1093.,  997.,  976., 1042., 1012.,
#          972.]),
#  array([6.33776156e-05, 1.00045729e-01, 2.00028081e-01, 3.00010432e-01,
#         3.99992784e-01, 4.99975136e-01, 5.99957487e-01, 6.99939839e-01,
#         7.99922190e-01, 8.99904542e-01, 9.99886894e-01]),
#  <BarContainer object of 10 artists>)

# %%
from scipy import stats
params=stats.uniform.fit(x)

# %%
dist=stats.uniform(loc=params[0], scale=params[1])

# %%
sm.qqplot(x, dist=dist, line="45")
plt.title("QQ plot of Uniform Distribution with Uniform fit")
plt.show()

# %% [markdown]
# # log log plot for Pareto distribution

# %%
alpha=3
xm=1

x=np.linspace(0.1, 10, 1000)

# %%
y=alpha*(xm**alpha)/x**(alpha+1)

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(np.log(x), np.log(y))
plt.title("Pareto Distribution")
plt.xlabel("Log x")
plt.ylabel("Log y")
plt.show()

# %%
x=stats.pareto.rvs(b=alpha, scale=xm, size=1000)

# %%
plt.hist(x)
plt.show()

# %%
params=stats.pareto.fit(x, floc=0)

# %%
dist=stats.pareto(b=params[0], scale=params[2])

# %%
fig=sm.qqplot(x, dist=dist, line="45")
plt.title("QQplot of Pareto Distribution fit")
plt.show()

# %% [markdown]
# # Transormers - Function Transformer - Log Transformer

# %%
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv("titanic.csv")[["Age", "Fare", "Survived"]]
df
# Out:
#       Age     Fare  Survived
# 0    22.0   7.2500         0
# 1    38.0  71.2833         1
# 2    26.0   7.9250         1
# 3    35.0  53.1000         1
# 4    35.0   8.0500         0
# ..    ...      ...       ...
# 886  27.0  13.0000         0
# 887  19.0  30.0000         1
# 888   NaN  23.4500         0
# 889  26.0  30.0000         1
# 890  32.0   7.7500         0
#
# [891 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Age         177
# Fare          0
# Survived      0
# dtype: int64

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df.isnull().sum()
# Out:
# Age         0
# Fare        0
# Survived    0
# dtype: int64

# %%
X=df.iloc[:, 0:2]
y=df.iloc[:,2]

# %%
X
# Out:
#            Age     Fare
# 0    22.000000   7.2500
# 1    38.000000  71.2833
# 2    26.000000   7.9250
# 3    35.000000  53.1000
# 4    35.000000   8.0500
# ..         ...      ...
# 886  27.000000  13.0000
# 887  19.000000  30.0000
# 888  29.699118  23.4500
# 889  26.000000  30.0000
# 890  32.000000   7.7500
#
# [891 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=4)

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
sns.distplot(X_train["Age"])
plt.title("Age PDF")

plt.subplot(122)
stats.probplot(X_train["Age"], dist="norm", plot=plt)
plt.title("Age QQ plot")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
sns.distplot(X_train["Fare"])
plt.title("Fare PDF")

plt.subplot(122)
stats.probplot(X_train["Fare"], dist="norm", plot=plt)
plt.title("Fare QQ plot")
plt.show()

# %%
lr=LogisticRegression()
dt=DecisionTreeClassifier()

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
lr_pred=lr.predict(X_test)

# %%
dt_pred=dt.predict(X_test)

# %%
print(f"LR accuracy : {accuracy_score(lr_pred, y_test)}")
print(f"DT accuracy : {accuracy_score(dt_pred, y_test)}")
# Out:
# LR accuracy : 0.6983240223463687
# DT accuracy : 0.6480446927374302

# %%
trf=FunctionTransformer(func=np.log1p)

# %%
X_train_trf=trf.fit_transform(X_train)
X_test_trf=trf.transform(X_test)

# %%
lr.fit(X_train_trf, y_train)
# Out:
# LogisticRegression()

# %%
dt.fit(X_train_trf, y_train)
# Out:
# DecisionTreeClassifier()

# %%
lr_pred_trf=lr.predict(X_test_trf)

# %%
dt_pred_trf=dt.predict(X_test_trf)

# %%
print(f"LR Trf accuracy : {accuracy_score(lr_pred_trf, y_test)}")
print(f"DT Trf accuracy : {accuracy_score(dt_pred_trf, y_test)}")
# Out:
# LR Trf accuracy : 0.6871508379888268
# DT Trf accuracy : 0.6703910614525139

# %%
X_transformed=trf.fit_transform(X)

# %%
print("LR Cross val score :", np.mean(cross_val_score(lr, X_transformed, y, scoring="accuracy", cv=10)))
print("DT Cross val score :", np.mean(cross_val_score(dt, X_transformed, y, scoring="accuracy", cv=10)))
# Out:
# LR Cross val score : 0.678027465667915
# DT Cross val score : 0.6588639200998752

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
stats.probplot(X_train["Age"], dist="norm", plot=plt)
plt.title("Age before Log")

plt.subplot(122)
stats.probplot(X_train_trf["Age"], dist="norm", plot=plt)
plt.title("Age after Log")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
stats.probplot(X_train["Fare"], dist="norm", plot=plt)
plt.title("Fare before Log")

plt.subplot(122)
stats.probplot(X_train_trf["Fare"], dist="norm", plot=plt)
plt.title("Fare after Log")
plt.show()

# %%
final_trf=ColumnTransformer([("log", FunctionTransformer(np.log1p), ["Fare"])], remainder="passthrough")

# %%
X_train_final_trf=final_trf.fit_transform(X_train)
X_test_final_trf=final_trf.transform(X_test)

# %%
lr.fit(X_train_final_trf, y_train)
dt.fit(X_train_final_trf, y_train)
# Out:
# DecisionTreeClassifier()

# %%
lr_pred_final=lr.predict(X_test_final_trf)
dt_pred_final=dt.predict(X_test_final_trf)

# %%
print("Accuracy for lr :", accuracy_score(lr_pred_final, y_test))
print("Accuracy for dt :", accuracy_score(dt_pred_final, y_test))
# Out:
# Accuracy for lr : 0.6871508379888268
# Accuracy for dt : 0.6703910614525139
